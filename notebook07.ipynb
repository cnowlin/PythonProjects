# %% [markdown]
# # Notebook 07
# ### IS6713 - Summer 2020
#
# Instructions:
# 1. Add the lines of code required to obtain the requested output.
#
# 2. The code should be inserted where requested
#
# 3. Do not modify other parts of this notebook.
#
# 4. Remember to write in your name and abc123 in the first cell of this notebook.
#
# 5. Upload the notebook on Blackboard before the deadline!
# __________________________________________________________
#
# Name: Chelsea L. Nowlin
# abc123: voi967

# %% [markdown]
# # Exercise 7.1
#
# Write a class named “CheckingAccount” that contains the currentbalanceof the account (an int) and the following methods:
#
# - **init** - takes a “balance” parameter to initialize the data (balance)of the object. Remember, the method init is implemented as \_\_init\_\_
# - **withdraw** - takes an input parameter “amount” and modifies thedata by reducing the balance.  If “amount” results in an overdraw,subtract an extra 20 dollars.  This method should return the balancebalance.
# - **deposit** - takes an input parameter “amount” and modifies the databy increasing the balance by “amount”.
#
# Write a few test cases to check your work

# %%
# write your code here
class CheckingAccount:
    balance = 0
    def _init_(self):
        self.balance = 0
    def deposit(self):
        amount = float(input("Enter an amount to be deposited: "))
        self.balance += amount
        print("\n Amount deposited: ", amount)
    def withdraw(self):
        amount = float(input("Enter an amount to withdraw: "))
        if self.balance >= amount:
            self.balance -= amount
            print("\n Amount withdrawn: ", amount)
        else:
            self.balance -= float(20)
    def display(self):
        print("\n Net avaliable balance= ", self.balance)
        
s = CheckingAccount()
s.deposit()
s.withdraw()
s.display()
# Out:
# Enter an amount to be deposited: 100
#
#  Amount deposited:  100.0
# Enter an amount to withdraw: 120

# %%
s.withdraw()
# Out:
# Enter an amount to withdraw: 80
#
#  Amount withdrawn:  80.0

# %%
s.display()
# Out:
#  Net avaliable balance:  0.0

# %%
s.withdraw()
# Out:
# Enter an amount to withdraw: 50

# %%
s.display()
# Out:
#  Net avaliable balance:  -20.0

# %% [markdown]
# # Exercise 7.2
#
# Answer the following questions before running the code below:
#
# - What are the parent and child classes here?
# parent class = Spell
#     child - Accio
#     child - Confundo
#
# - What does the code print out?  (Try figuring it out without running itin Python)
# self, spell incantation, the name of the spell, and description of what it does
#
# - Which get description method is called when ‘studyspell(Confundo())’ is executed?  Why?
# def get_description(self):
#         return "Causes the victim to become confused and befuddled."
#
# because the method is called under the same class for Confundo
#
# - What do we need to do so that ‘print(Accio())’ will print theappropriate description (‘This charm summons an object to the caster,potentially over a significant distance’)?  Change to code to do this.
#
# def get_description(self):
#         return "This charm summons an object to the caster,potentially over a significant distance."
# Will need to be added to the class for Accio so the get description method is called in the class so it prints the correct description when calling the Accio class to print.

# %%
class Spell:
    name = ''
    incantation = ''
    
    def __init__(self, incantation, name):
        self.name = name
        self.incantation = incantation
        
    def __str__(self):
        return self.name + " " + self.incantation + "\n" + self.get_description()
    
    def get_description(self):
        return "No description"
    
    def execute(self):
        print(self.incantation)
        
class Accio(Spell):
    def __init__(self):
        Spell.__init__(self, "Accio", "Summoning Charm")
        
    def get_description(self):
        return "This charm summons an object to the caster,potentially over a significant distance."
        
class Confundo(Spell):
    def __init__(self):
        Spell.__init__(self, "Confundo", "Confundus Charm")
        
    def get_description(self):
        return "Causes the victim to become confused and befuddled."
    
def study_spell(spell):
    print(spell)

# %%
# DO NOT RUN THIS CELL UNTIL YOU ANSWER THE QUESTIONS ABOVE!
spell = Accio()
spell.execute()
study_spell(spell)
study_spell(Confundo())
# Out:
# Accio
# Summoning Charm Accio
# This charm summons an object to the caster,potentially over a significant distance.
# Confundus Charm Confundo
# Causes the victim to become confused and befuddled.

# %% [markdown]
# # Exercise 7.3
# Your goal is to split the text into a list of tokenized sentences and calculate the length of each sentence. Tasks:
# - Step 1: Load the raw text (already provided)
# - Step 2: Segment the text into a list of sentences using the sent_tokenizer class from nltk
# - Step 3: Tokenize each sentence using nltk.word_tokenize()
# - Step 4: Count the number of terms (tokens) in each sentence, store it into a list, and calculate and print the average sentence length

# %%
# Step 1
fhandle = open("Frankenstein_excerpt.txt")
text = ''
for line in fhandle:
    text += line.strip() + ' '
fhandle.close()
## Trim out the initial comments. 
textRaw = text[250:]   # text is the raw text we are working with

# %%
# Step 2 sentence split
# Use textRaw as your input and split the text in sentences
# write your code here
from nltk.tokenize import sent_tokenize, word_tokenize
textRaw.split()
sents = sent_tokenizer.tokenize(textRaw)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-110-40b50d9ccacb> in <module>
#       4 from nltk.tokenize import sent_tokenize, word_tokenize
#       5 textRaw.split()
# ----> 6 sents = sent_tokenizer.tokenize(textRaw)
#       7
#       8
#
# NameError: name 'sent_tokenizer' is not defined

# %%
# Step 3 tokenization
# Tokenize each sentence of the outcome of Step 2, a list of sentences. 
# write your code here
import nltk

tokens = nltk.sent_tokenize(textRaw)
tokens
# Out:
# ['Frankenstein,  or the Modern Prometheus   by  Mary Wollstonecraft (Godwin) Shelley     Letter 1   St. Petersburgh, Dec. 11th, 17--  TO Mrs. Saville, England  You will rejoice to hear that no disaster has accompanied the commencement of an enterprise which you have regarded with such evil forebodings.',
#  'I arrived here yesterday, and my first task is to assure my dear sister of my welfare and increasing confidence in the success of my undertaking.',
#  'I am already far north of London, and as I walk in the streets of Petersburgh, I feel a cold northern breeze play upon my cheeks, which braces my nerves and fills me with delight.',
#  'Do you understand this feeling?',
#  'This breeze, which has travelled from the regions towards which I am advancing, gives me a foretaste of those icy climes.',
#  'Inspirited by this wind of promise, my daydreams become more fervent and vivid.',
# ...

# %%
print(tokens)
# Out:
# ['Frankenstein,  or the Modern Prometheus   by  Mary Wollstonecraft (Godwin) Shelley     Letter 1   St. Petersburgh, Dec. 11th, 17--  TO Mrs. Saville, England  You will rejoice to hear that no disaster has accompanied the commencement of an enterprise which you have regarded with such evil forebodings.', 'I arrived here yesterday, and my first task is to assure my dear sister of my welfare and increasing confidence in the success of my undertaking.', 'I am already far north of London, and as I walk in the streets of Petersburgh, I feel a cold northern breeze play upon my cheeks, which braces my nerves and fills me with delight.', 'Do you understand this feeling?', 'This breeze, which has travelled from the regions towards which I am advancing, gives me a foretaste of those icy climes.', 'Inspirited by this wind of promise, my daydreams become more fervent and vivid.', 'I try in vain to be persuaded that the pole is the seat of frost and desolation; it ever presents itself to my imagi
# ...

# %%
# Step 4: Starting from the list of tokenized sentences:
#        - count how many tokens per sentence
#        - store in a list, and
#        - calculate the average lenght
# write your code here
count = nltk.FreqDist(tokens)
print(len(count))
# Out:
# 48

# %% [markdown]
# # Exercise 7.4
#
# Analyze **Frankenstein_excerpt.txt** following the steps described below:
# - Normalize (lower case)
# - Tokenize (use nltk.word_tokenize())
# - Eliminate the stop-words
# - Eliminate the punctuation
# - Lemmatize
# - Calculate the Frequency
# - Print the 25 most frequent terms
# - Plot the 25 most frequent terms

# %%
import nltk

# %%
# Load raw text
fhandle = open("Frankenstein_excerpt.txt")
text = ''
for line in fhandle:
    text += line.strip() + ' '
fhandle.close()
## Trim out the initial comments. 
textRaw = text[250:]   # text is the raw text we are working with

# %%
text.lower()
# Out:
# "this ebook is for the use of anyone anywhere at no cost and with almost no restrictions whatsoever.  you may copy it, give it away or re-use it under the terms of the project gutenberg license included with this ebook or online at www.gutenberg.net  frankenstein,  or the modern prometheus   by  mary wollstonecraft (godwin) shelley     letter 1   st. petersburgh, dec. 11th, 17--  to mrs. saville, england  you will rejoice to hear that no disaster has accompanied the commencement of an enterprise which you have regarded with such evil forebodings.  i arrived here yesterday, and my first task is to assure my dear sister of my welfare and increasing confidence in the success of my undertaking.  i am already far north of london, and as i walk in the streets of petersburgh, i feel a cold northern breeze play upon my cheeks, which braces my nerves and fills me with delight.  do you understand this feeling?  this breeze, which has travelled from the regions towards which i am advancing, giv
# ...

# %%
# Step 1: Normalize
# write your code here
import re
re.split(r'[ \t\n]+', text)
# Out:
# ['This',
#  'eBook',
#  'is',
#  'for',
#  'the',
#  'use',
#  'of',
#  'anyone',
#  'anywhere',
#  'at',
#  'no',
#  'cost',
#  'and',
#  'with',
#  'almost',
#  'no',
#  'restrictions',
#  'whatsoever.',
#  'You',
#  'may',
#  'copy',
#  'it,',
#  'give',
#  'it',
#  'away',
#  'or',
#  're-use',
#  'it',
#  'under',
#  'the',
#  'terms',
#  'of',
#  'the',
#  'Project',
#  'Gutenberg',
#  'License',
#  'included',
#  'with',
#  'this',
#  'eBook',
#  'or',
#  'online',
#  'at',
#  'www.gutenberg.net',
#  'Frankenstein,',
#  'or',
#  'the',
#  'Modern',
#  'Prometheus',
#  'by',
#  'Mary',
#  'Wollstonecraft',
#  '(Godwin)',
#  'Shelley',
#  'Letter',
#  '1',
#  'St.',
#  'Petersburgh,',
#  'Dec.',
#  '11th,',
#  '17--',
#  'TO',
#  'Mrs.',
#  'Saville,',
#  'England',
#  'You',
#  'will',
#  'rejoice',
#  'to',
#  'hear',
#  'that',
#  'no',
#  'disaster',
#  'has',
#  'accompanied',
#  'the',
#  'commencement',
#  'of',
#  'an',
#  'enterprise',
#  'which',
#  'you',
#  'have',
# ...

# %%
# Step 2: Tokenize (use nltk.word_tokenize())
# write your code here
import nltk
nltk.download('punkt')

words = nltk.word_tokenize(text)
words
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\razzb\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ['This',
#  'eBook',
#  'is',
#  'for',
#  'the',
#  'use',
#  'of',
#  'anyone',
#  'anywhere',
#  'at',
#  'no',
#  'cost',
#  'and',
#  'with',
#  'almost',
#  'no',
#  'restrictions',
#  'whatsoever',
#  '.',
#  'You',
#  'may',
#  'copy',
#  'it',
#  ',',
#  'give',
#  'it',
#  'away',
#  'or',
#  're-use',
#  'it',
#  'under',
#  'the',
#  'terms',
#  'of',
#  'the',
#  'Project',
#  'Gutenberg',
#  'License',
#  'included',
#  'with',
#  'this',
#  'eBook',
#  'or',
#  'online',
#  'at',
#  'www.gutenberg.net',
#  'Frankenstein',
#  ',',
#  'or',
#  'the',
#  'Modern',
#  'Prometheus',
#  'by',
#  'Mary',
#  'Wollstonecraft',
#  '(',
#  'Godwin',
#  ')',
#  'Shelley',
#  'Letter',
#  '1',
#  'St.',
#  'Petersburgh',
#  ',',
#  'Dec.',
#  '11th',
#  ',',
#  '17',
#  '--',
#  'TO',
#  'Mrs.',
#  'Saville',
#  ',',
# ...

# %%
# Step 3: Eliminate the stop-words
# write your code here
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
stoplist = stopwords.words('english')

cleanwordlist = [word for word in text.split() if word not in stoplist]
print(cleanwordlist)
# Out:
# ['This', 'eBook', 'use', 'anyone', 'anywhere', 'cost', 'almost', 'restrictions', 'whatsoever.', 'You', 'may', 'copy', 'it,', 'give', 'away', 're-use', 'terms', 'Project', 'Gutenberg', 'License', 'included', 'eBook', 'online', 'www.gutenberg.net', 'Frankenstein,', 'Modern', 'Prometheus', 'Mary', 'Wollstonecraft', '(Godwin)', 'Shelley', 'Letter', '1', 'St.', 'Petersburgh,', 'Dec.', '11th,', '17--', 'TO', 'Mrs.', 'Saville,', 'England', 'You', 'rejoice', 'hear', 'disaster', 'accompanied', 'commencement', 'enterprise', 'regarded', 'evil', 'forebodings.', 'I', 'arrived', 'yesterday,', 'first', 'task', 'assure', 'dear', 'sister', 'welfare', 'increasing', 'confidence', 'success', 'undertaking.', 'I', 'already', 'far', 'north', 'London,', 'I', 'walk', 'streets', 'Petersburgh,', 'I', 'feel', 'cold', 'northern', 'breeze', 'play', 'upon', 'cheeks,', 'braces', 'nerves', 'fills', 'delight.', 'Do', 'understand', 'feeling?', 'This', 'breeze,', 'travelled', 'regions', 'towards', 'I', 'advancing,', 'g
# ...

# %%
# Step 4: Eliminate the punctuation
# write your code here
import string
def remove_punctuation(words):
    nopunct = "".join([c for c in text if c not in string.punctuation])
    return nopunct

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
text_nopunct = remove_punctuation(words)

# %%
# Step 5: Lemmatize
# write your code here
import nltk
from nltk.stem import WordNetLemmatizer

textLemma = []
for tok in cleanTok:
    textLemma.append(wordnet.lemmatizer.lemmatize(tok))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-96-b87b11b575c8> in <module>
#       5
#       6 textLemma = []
# ----> 7 for tok in cleanTok:
#       8     textLemma.append(wordnet.lemmatizer.lemmatize(tok))
#
# NameError: name 'cleanTok' is not defined

# %%
# Step 6: Calculate the Frequency
# write your code here
import operator


freq_dis={}    

for x in words:
    if x in freq_dis:
        freq_dis[x]+=1
    else:
        freq_dis[x]=1

sorted_freq_dist= sorted(freq_dis.items(), key=operator.itemgetter(1), reverse=True)

# %%
# Step 7: Print the 25 most frequent terms
# write your code here
print(sorted_freq_dist[:25])
# Out:
# [(',', 78), ('the', 70), ('I', 46), ('and', 44), ('.', 42), ('my', 39), ('of', 38), ('to', 34), ('a', 28), ('in', 24), ('which', 19), ('with', 14), ('for', 12), ('that', 12), ('may', 11), ('are', 11), ('is', 10), (';', 10), ('on', 10), ('as', 9), ('me', 9), ('by', 8), ('have', 8), ('or', 7), ('this', 7)]

# %%
# Step 8: Plot the 25 most frequent terms
# write your code here
def graph():
    dic = nltk.FreqDist(words)
    FreqDist(text).plot(25, cumulative=False)
