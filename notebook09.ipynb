# %% [markdown]
# # Notebook 09
# ### IS6713 - Summer 2020
#
# Instructions:
# 1. Add the lines of code required to obtain the requested output.
#
# 2. The code should be inserted where requested
#
# 3. Do not modify other parts of this notebook.
#
# 4. Remember to write in your name and abc123 in the first cell of this notebook.
#
# 5. Upload the notebook on Blackboard before the deadline!

# %% [markdown]
# Name: Chelsea L. Nowlin
# abc123: voi967

# %% [markdown]
# ## Exercise 9.1
# ### IRIS
# Do the following:
# - Load the **iris.csv** dataset into a numpy array. The first 4 columns are the  features/attributes. The last column is the class. Simply load the class as a list of strings. You can use the CVS method to load the features into a list of lists (X) and to load the gold label as a list (y). Then, convert X and y into a numpy array (hint: use np.array() for the conversion).
# - Use train_test_split() to split the iris dataset into train and test. (use 0.2 for the test_size)
# - Train an SVM classifier on the train split and evaluate it using accuracy on the test split.
# - Try using a different classifier, a random forest, and see how it compares to the SVM classifier.
#
# Note that this is a toy dataset, so all scores will be high.

# %%
## STep 1 Load the data
import csv
import numpy as np
X = [] # Will be a list of lists
y = [] # will be a list

## Write below your code
with open('iris.csv') as f:
    for row in f:
        columns = row.strip().split(',')
        X.append([float(x) for x in columns[:-1]])
        y.append(columns[-1])
        
X = np.array(X)
y = np.array(y)

# %%
assert(len(set(y))==3)

# %%
(len(set(y))==3)
# Out:
# True

# %%
set(y)
# Out:
# {'Iris-setosa', 'Iris-versicolor', 'Iris-virginica'}

# %%
len(y)
# Out:
# 150

# %%
### Step 2: Split data in train and test
from sklearn.model_selection import train_test_split

# Write your code here
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
### Step 3: Train a SVM classifier, predict the labels, and calculate the accuracy
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# Write your code here
clf  = SVC()
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)

print("SVM accuracy: {}".format(accuracy))
# Out:
# SVM accuracy: 1.0

# %%
### Step 4: Train a Random Forest Classifier, predict the labels, measure the accuracy, and print the classification_report
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# Write your code here
RFC = RandomForestClassifier(n_estimators=150, random_state=0)
RFC.fit(X_train, y_train)

y_pred = RFC.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)

print("RF accuracy: {}".format(accuracy))
# Out:
# RF accuracy: 1.0

# %% [markdown]
# ## Exercise 9.2
# A sentiment analysis job about the problems of each major U.S. airline. Twitter data was scraped from February of 2015 and contributors were asked to first classify positive, negative, and neutral tweets, followed by categorizing negative reasons (such as "late flight" or "rude service").
# The data I am providing is a reformatted version of the Kaggle one. For example, "neutral" Tweets are not included for simplicity. The dataset includes three fields: **airline**, **full_text**, and **gold_label**.
# Tasks:
# - Load the **w9_airlinetwitter.jsonl** dataset
# - Plot the Percentage of tweets by airline
# - Vectorize using the TFIDF approach
# - Split the dataset in train (80%) and test (20%) sets
# - Train the RandomForest Classifier over the train set
# - Predict the labels of the test set using the trained model
# - Calculate and print:
#   - Classification report
#   - Confusion matrix
#   - Accuracy score

# %%
import json
with open('w9_airlinetwitter.jsonl', 'r') as fp:
    lines = fp.readlines()
    for row in fp:
        print(row.strip())
        break

# %%
### Step 1: load the dataset
import json
with open('w9_airlinetwitter.jsonl', 'r') as fp:
    lines = list(fp.readlines())       


dataset = [fp]
dataset.append(lines)
#'airline:', 'full_text:', 'gold_label:'

# %%
assert(len(dataset)==11541)
print("Dataset Correctly Loaded")
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-61-757b16a060fb> in <module>
# ----> 1 assert(len(dataset)==11541)
#       2 print("Dataset Correctly Loaded")
#
# AssertionError:

# %%
(len(dataset)==11541)
# Out:
# False

# %%
len(lines)
# Out:
# 11541

# %%
lines[0]
# Out:
# '{"airline": "Virgin America", "full_text": "@VirginAmerica plus you\'ve added commercials to the experience... tacky.", "gold_label": "positive"}\n'

# %% [markdown]
# ### Know your data
# Plot with the library Pandas (install **Pandas** if you don't have it yet)

# %%
## Step 2: plot the percentage of tweets by airline
## Hint: import pandas and convert your dataset in a DataFrame (df = pd.DataFrame(dataset))
import pandas as pd
df = pd.DataFrame(lines)
df[0].value_counts().plot(kind = 'pie', autopct='%1.0f%%', title='0=negative, 1=positive')
# Out:
# ---------------------------------------------------------------------------
# ParseException                            Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\matplotlib\mathtext.py in parse(self, s, fonts_object, fontsize, dpi)
#    2597         try:
# -> 2598             result = self._expression.parseString(s)
#    2599         except ParseBaseException as err:
#
# ~\anaconda3\lib\site-packages\pyparsing.py in parseString(self, instring, parseAll)
#    1946                 # catch and re-raise exception from here, clears out pyparsing internal stack trace
# -> 1947                 raise exc
#    1948         else:
#
# ~\anaconda3\lib\site-packages\pyparsing.py in parseString(self, instring, parseAll)
#    1936         try:
# -> 1937             loc, tokens = self._parse(instring, 0)
#    1938             if parseAll:
#
# ~\anaconda3\lib\site-packages\pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1837                 try:
# ...

# %%
set(df[0])
# Out:
# {'{"airline": "US Airways", "full_text": "@USAirways customer service at its finest", "gold_label": "positive"}\n',
#  '{"airline": "United", "full_text": "@United flight was scheduled for 11:56, it\'s 1:05 and we haven\'t moved. I have never been on a flight where everyone moved without a sense", "gold_label": "negative"}\n',
#  '{"airline": "Delta", "full_text": "@JetBlue but you guys should know that musicians are very sensitive about the safety of their instruments when flying. For good reason.", "gold_label": "negative"}\n',
#  '{"airline": "US Airways", "full_text": "@USAirways \\"good news. We\'ve located the crew and made contact with them\\". flight was supposed to leave 4 minutes ago. #usairwaysfail", "gold_label": "negative"}\n',
#  '{"airline": "Southwest", "full_text": "@SouthwestAir I\'m upset because we were lied to. Was told ice on runway, but EVERY other carrier was able to fly. Airport confirmed no ice!", "gold_label": "negative"}\n',
# ...

# %% [markdown]
# ### Analysis Section

# %%
## Step 3 - Vectorize the dataset
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TFidVectorizer

vectorizer = TFidVectorizer (max_features=11541, min_df=7, max_df=0.8,
                            stop_words=stopwords.words("english"))
processed_features_vec = vectorizer.fit.transform(features).toarray()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-74-5248eb72815f> in <module>
#       1 ## Step 3 - Vectorize the dataset
#       2 from nltk.corpus import stopwords
# ----> 3 from sklearn.feature_extraction.text import TFidVectorizer
#       4
#       5 vectorizer = TFidVectorizer (max_features=11541, min_df=7, max_df=0.8,
#
# ImportError: cannot import name 'TFidVectorizer' from 'sklearn.feature_extraction.text' (C:\Users\razzb\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py)

# %%
## Step 4 - Split in train and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(processed_features_vec,
                                                   gold_labels, test_sizes=0.2,
                                                   random_state=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-77-59e5f6a84abc> in <module>
#       1 ## Step 4 - Split in train and test
#       2 from sklearn.model_selection import train_test_split
# ----> 3 X_train, X_test, y_train, y_test = train_test_split(processed_features_vec,
#       4                                                    gold_labels, test_sizes=0.2,
#       5                                                    random_state=0)
#
# NameError: name 'processed_features_vec' is not defined

# %% [raw]
# ## Step 5: train the classifier
# from sklearn.ensemble import RandomForestClassifier
#
# text_classifier = RandomForestClassifier(n_estimators=11541, random_state=0)
# text_classifier.fit(X_train, y_train)

# %%
## Step 6: Predict the labels
predictions = text_classifier.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-82-b9f012c1bb54> in <module>
#       1 ## Step 6: Predict the labels
# ----> 2 predictions = text_classifier.predict(X_test)
#
# NameError: name 'text_classifier' is not defined

# %%
## Step 7: Assess the performance (Accuracy, Confusion Matrix, Classification Report)
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

tn, fp, fn, tp = confusion_matrix(y_test, predictions).ravel()
print("TP", tp, "TN", tn, "FP", fp, "FN", fn)
print(confusion_matrix(y_test, predictions))
print(classification_report(y_test, predictions))
print("RF Accuracy: {0.2f}".format(accouracy_score(y_test, predictions)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-83-5b048339c41f> in <module>
#       2 from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
#       3
# ----> 4 tn, fp, fn, tp = confusion_matrix(y_test, predictions).ravel()
#       5 print("TP", tp, "TN", tn, "FP", fp, "FN", fn)
#       6 print(confusion_matrix(y_test, predictions))
#
# NameError: name 'y_test' is not defined
